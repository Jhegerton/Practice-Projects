# %%
from math import sqrt, ceil
from functools import reduce
from operator import mul

# %%
def is_prime(number):
    min_val = 2
    max_val = ceil(sqrt(number)) + 1

    for num in (total_range := range(min_val, max_val)):
        if number % num == 0:
            return False
            
    return True

# %%
def get_prime_factors(number_to_factor):
    factors = []
    min_val = 2
    max_val = ceil(sqrt(number_to_factor)) + 1

    if not is_prime(number_to_factor):
        for num in (total_range := range(min_val, max_val)):
            if number_to_factor % num == 0:
                factors.append(num)
                factors.extend(get_prime_factors(number_to_factor//num))
                return [factor for factor in factors if factor != 1]
    return [number_to_factor]

# %%
facts = get_prime_factors(2048)

# %%
facts
# Out:
# [2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2]

# %%
reduce(mul,facts)
# Out:
# 2048
