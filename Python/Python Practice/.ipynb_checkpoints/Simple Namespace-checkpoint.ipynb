# %%
from types import SimpleNamespace as sn

# %%
my_car = sn(make="Honda", model="Civic", trim="LX", year=2014)

# %%
repr(my_car)
# Out:
# "namespace(make='Honda', model='Civic', trim='LX', year=2014)"

# %%
my_car_dict = vars(my_car)

# %%
my_car_dict
# Out:
# {'make': 'Honda', 'model': 'Civic', 'trim': 'LX', 'year': 2014}
