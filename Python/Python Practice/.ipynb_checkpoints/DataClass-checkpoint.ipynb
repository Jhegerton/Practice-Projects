# %%
from dataclasses import dataclass

# %%
@dataclass
class Car:
    make: str
    model: str
    trim: str
    year: int

    def __str__(self):
        return f"{self.year} {self.make} {self.model} {self.trim}"

# %%
my_car = Car("Honda", "Civic", "LX", 2014)

# %%
my_car
# Out:
# Car(make='Honda', model='Civic', trim='LX', year=2014)

# %%
print(my_car)
# Out:
# 2014 Honda Civic LX
